# %% [markdown]
# <a href="https://colab.research.google.com/github/Victorbenavides/Mezcla_Gaussiana/blob/main/Mezcla_de_Gaussianas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from sklearn.mixture import GaussianMixture
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm
X_train = np.array([[2, 2], [3, 4], [0, 0], [11, 2], [9, 4], [10, 0]])
gm = GaussianMixture(n_components=2).fit(X_train)
print ("Weights: ")
print (gm.weights_)
print ("Means: ")
print (gm.means_ )
print ("Covariances :")
print (gm.covariances_)
print (gm.predict([[0, 0], [12, 3],]))
x = np.linspace(-20.0, 30.0)
y = np.linspace(-20.0, 40.0)
X, Y = np.meshgrid(x, y)
XX = np.array([X.ravel(), Y.ravel()]).T
Z = -gm.score_samples(XX)
Z = Z.reshape(X.shape)
CS = plt.contour( X, Y, Z, norm=LogNorm(vmin=1.0, vmax=1000.0), levels=np.logspace(0, 3, 10))
CB = plt.colorbar(CS, shrink=0.8, extend="both")
plt.scatter(X_train[:, 0], X_train[:, 1], 0.8)
plt.title("Negative log-likelihood predicted by a GMM")
plt.axis("tight")
plt.show()
# Out:
# Weights:
# [0.5 0.5]
# Means:
# [[10.          2.        ]
#  [ 1.66666667  2.        ]]
# Covariances :
# [[[ 0.66666767 -0.66666667]
#   [-0.66666667  2.66666767]]
#
#  [[ 1.55555656  2.        ]
#   [ 2.          2.66666767]]]
# [1 0]

# %%
import numpy as np
from sklearn.mixture import GaussianMixture
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm
X_train = np.array([[2, 2], [3, 4], [0, 0], [11, 2], [9, 4], [10, 0]])
gm = GaussianMixture(n_components=3).fit(X_train)
print ("Weights: ")
print (gm.weights_)
print ("Means: ")
print (gm.means_ )
print ("Covariances :")
print (gm.covariances_)
print (gm.predict([[0, 0], [12, 3],[10,1]]))
x = np.linspace(-20.0, 30.0)
y = np.linspace(-20.0, 40.0)
X, Y = np.meshgrid(x, y)
XX = np.array([X.ravel(), Y.ravel()]).T
Z = -gm.score_samples(XX)
Z = Z.reshape(X.shape)
CS = plt.contour( X, Y, Z, norm=LogNorm(vmin=1.0, vmax=1000.0), levels=np.logspace(0, 3, 10))
CB = plt.colorbar(CS, shrink=0.8, extend="both")
plt.scatter(X_train[:, 0], X_train[:, 1], 0.8)
plt.title("Negative log-likelihood predicted by a GMM")
plt.axis("tight")
plt.show()
# Out:
# Weights:
# [0.5        0.33333333 0.16666667]
# Means:
# [[10.   2. ]
#  [ 2.5  3. ]
#  [ 0.   0. ]]
# Covariances :
# [[[ 6.66667667e-01 -6.66666667e-01]
#   [-6.66666667e-01  2.66666767e+00]]
#
#  [[ 2.50001000e-01  5.00000000e-01]
#   [ 5.00000000e-01  1.00000100e+00]]
#
#  [[ 1.00000000e-06  0.00000000e+00]
#   [ 0.00000000e+00  1.00000000e-06]]]
# [2 0 0]
